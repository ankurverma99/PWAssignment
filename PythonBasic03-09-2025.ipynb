# %% [raw]
# 1. What is Python, and why is it popular ?
# Ans>   Python is a high-level, interpreted programming language known for its simplicity and readability.
#    Versatility: Python is a general-purpose language, meaning it can be used for a wide range of applications, including web development, data analysis, artificial intelligence, machine learning, automation, scientific computing, and more.
#
# Easy to Learn and Read: Python emphasizes readability and simplicity, making it an excellent choice for beginners. Its clean syntax reduces the cost of program maintenance and development.
#
# Interpretation and Compilation: Python is an interpreted language, which means code is executed line by line, making it easier to debug and test. However, Python can also be compiled into bytecode for improved performance using tools like PyInstaller, Cython, or Nuitka.
#
# Dynamic Typing: Python uses dynamic typing, meaning you don't need to declare variable types explicitly. This flexibility allows for rapid development and prototyping.
#
# Community Support: Python has a vast and active community of developers who contribute to its ecosystem by creating libraries, frameworks, and tools. This community support makes it easy to find solutions to problems, learn new techniques, and collaborate on projects.

# %% [raw]
# 2.What is an interpreter in Python?
#  Ans>   In Python, an interpreter is a program that reads and executes Python code line by line. It converts the high-level Python source code into machine-readable instructions at runtime, without the need for prior compilation into a binary executable.

# %% [raw]
# 3.What are pre-defined keywords in Python?
# Ans>Pre-defined keywords in Python are reserved words that have special meaning in the language. These words are part of the syntax and structure of Python and cannot be used as variable names, function names, or identifiers.
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %% [raw]
# 4.Can keywords be used as variable names ?
# Ans> No, keywords cannot be used as variable names in Python.
# Python reserves keywords for special functions and control structures in the language. Trying to use a keyword as a variable name will result in a SyntaxError.

# %% [raw]
# 5.What is mutability in Python?
# Ans> Objects/Containers whose value can be change after they are created are called mutable object or containers.
# E.g, list .
# my_list = [1, 2, 3]
# my_list[0] = 100
# print(my_list)
# # Output: [100, 2, 3]

# %% [raw]
# 6.Why are lists mutable, but tuples are immutable?
# Ans>List: Lists are meant to store data that may change.
# Common operations like adding, removing, or updating elements require mutability.
# my_list = [1, 2, 3]
# my_list[0] = 100
# print(my_list)
#  # Output: [100, 2, 3, 4]
# Tuples : Tuples are designed for fixed collections of items.
# They're often used for data integrity, like representing coordinates, RGB values, or function arguments.
# Immutability allows them to be hashable, so they can be used as dictionary keys or set elements.
# my_tuple = (1, 2, 3)
# my_tuple[0] = 100
# #'tuple' object does not support item assignment

# %% [raw]
# 7. What is the difference between “==” and “is” operators in Python ?
# Ans>'==' compares the value of the objects.
# 'is'  compares the memory address of objects.
#
# e.g:
# a = [1, 2, 3]
# b = [1, 2, 3]
#
# print(a == b)
# #Output : True – because their contents are the same
#
# print(a is b)
# #Output : False – they are two different list objects

# %% [raw]
# 8.What are logical operators in Python?
# Ans> Logical operators -> and,or and not
# Logical operators in Python are used to combine conditional statements (i.e., expressions that return True or False).
# e.g :
# And
# number = 42
# if( (number%2 == 0) and (number > 0) ):
#     print("number is even")
#
# #Output : number is even
#
# Or
#
# a = 10
# b = -5
#
# print(a > 0 or b > 0)
# print(a < 0 or b < 0)
#
# #Output :
# True
# True
#
# Not
#
# a = True
# print(not a)
#
# b = False
# print(not b)
#
# #Output
# False (inverse of True)
# True (inverse of False)

# %% [raw]
# 9.What is type casting in Python ?
#
# Ans> Converting of one data type to another data type is known as type casting or type conversion.
#
# Implicit : Implicit type conversion is a conversion which will performed by python intepreter without programe intervention.
# E.g ,
# a=5 -> int
# b=5.5 -> float
# c= a+b -> float
# print(c)
# #output : 10.5
#
# Explicit : Explicit type conversion (also called type casting) is when you manually convert one data type into another using built-in functions.
#
# E.g,
# x = "10"
# y = int(x)  # Explicitly converting string to integer
# print(y + 5)
# # Output: 15

# %% [raw]
# 10.What is the difference between implicit and explicit type casting?
# Ans>
# Implicit Type Casting (Automatic)
#
# 1.Done automatically by Python.
# 2.No user intervention required.
# 3.Usually occurs when converting smaller to larger data types to avoid data loss.
#
# Explicit Type Casting (Manual)
#
# 1.Done manually by the programmer.
# 2.Uses built-in functions like int(), float(), str(), etc.
# 3.Needed when Python can’t safely convert the data on its own.

# %% [raw]
# 11.What is the purpose of conditional statements in Python?
# Ans> Conditional statements in Python are used to make decisions in a program. They allow your code to execute certain blocks of code only if specific conditions are met.
# To control the flow of execution in a program based on whether a condition is True or False.
#
# Statement
# if	-> Executes a block of code if the condition is true.
# elif	-> Checks another condition if the previous if was false.
# else	-> Executes a block of code if none of the above conditions are true .
#
#
# E.g ,
# age = int(input("Enter you age"))
#
# if age < 18 :
#     print("You are minorty")
# elif 18<=age<=60 :
#     print("you are adult")
# else:
#     print(" you are senior citizen")
#
# #Output
# age = 15
# You are minorty

# %% [raw]
# 12.How does the elif statement work ?
# Ans>The elif statement stands for "else if" and is used in conditional decision-making. It lets you check multiple conditions one by one after an if statement.
# To test another condition if the previous if (or elif) condition was False.
#
# if condition1:
#     # runs if condition1 is True
# elif condition2:
#     # runs if condition1 is False and condition2 is True
# elif condition3:
#     # runs if all above are False and condition3 is True
# else:
#     # runs if none of the above conditions are True
#
# E.g,
#
# marks = 85
#
# if marks >= 90:
#     print("Grade: A")
# elif marks >= 80:
#     print("Grade: B")
# elif marks >= 70:
#     print("Grade: C")
# else:
#     print("Grade: D")
#
# #Output :
# Grade: B

# %% [raw]
# 13.What is the difference between for and while loops ?
# Ans>
# For Loop :
# 1.The for loop is used when you know in advance how many times you want to execute the block of code.
# 2.It iterates over a sequence (e.g., a list, tuple, string, or range) and executes the block of code for each item in the sequence.
# 3.The loop variable (variable) takes the value of each item in the sequence during each iteration.
#
# E.g,
# for i in range(5):
#     print(i)
#
# #Output : 0,1,2,3,4
#
# While Loop :
#
# 1.The while loop is used when you don't know in advance how many times you want to execute the block of code. It continues to execute as long as the specified condition is true.
# 2.It's important to make sure that the condition eventually becomes false; otherwise, the loop will run indefinitely, resulting in an infinite loop.
#
# E.g,
# count = 0
# while count < 5:
#     print(count)
#     count += 1
# #Output : 0,1,2,3,4

# %% [raw]
# 14.Describe a scenario where a while loop is more suitable than a for loop.
#
# Ans> A while loop is a control flow statement that allows you to repeatedly execute a block of code as long as a given condition is True.
#
# How does it work?
# The condition is checked before every iteration.
# If the condition is True, the code inside the loop runs.
# After running the code block, the condition is checked again.
# This repeats until the condition becomes False.
# When the condition is False, the loop stops and the program continues with the next code after the loop.
#
# Fill the bottle until it reaches 5 liters .
# We’ll assume you are adding 1 liter at a time.
#
# bottle = 0  # current amount in bottle
#
# while bottle < 5:
#     print(f"Filling... {bottle} liters filled.")
#     bottle += 1  # add 1 liter
#
# print("Bottle is full! (5 liters)")
#
# #Output
# Filling... 0 liters filled.
# Filling... 1 liters filled.
# Filling... 2 liters filled.
# Filling... 3 liters filled.
# Filling... 4 liters filled.
# Bottle is full! (5 liters)
